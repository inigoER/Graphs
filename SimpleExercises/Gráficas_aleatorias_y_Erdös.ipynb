# %%
import networkx as nx
import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# # Gráfica aleatoria

# %%
def random_graph(nv,ne):
  G = nx.Graph()
  pos_e = []
  for i in range(nv):
    for j in range(nv):
      pos_e.append([str(i+1),str(j+1)])
  chosen_edges = random.sample(pos_e, ne)
  for i in chosen_edges:
    G.add_edge(i[0],i[1])
  return G

# %%
G1 = random_graph(300,1000)

# %%
pos = nx.spring_layout(G1)
fig = plt.figure(1, figsize=(20,8), dpi=100)
nx.draw(G1,pos, with_labels=True)
plt.title("Random graph")
plt.show()

# %%
import collections
degree_sequence = sorted([d for n, d in G1.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots()
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d for d in deg])
ax.set_xticklabels(deg)

plt.show()

# %% [markdown]
# Como podemos ver, el grado promedio efectivamente es 2*(1000)/300 = 6.6, aprox 6.

# %% [markdown]
# Este método de gráficas aleatorias se usan en el modelado de redes sociales, epidemias, estructuras del internet, etc.

# %% [markdown]
# # Erdös-Rényi

# %%
G2 = nx.binomial_graph(300, 0.015)

# %%
pos = nx.spring_layout(G2)
fig = plt.figure(1, figsize=(20,8), dpi=100)
nx.draw(G2,pos, with_labels=True)
plt.title("Random graph")
plt.show()

# %%
import collections
degree_sequence = sorted([d for n, d in G2.degree()], reverse=True)  # degree sequence
# print "Degree sequence", degree_sequence
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

fig, ax = plt.subplots()
plt.bar(deg, cnt, width=0.80, color='b')

plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
ax.set_xticks([d for d in deg])
ax.set_xticklabels(deg)

plt.show()

# %% [markdown]
# Podemos ver que el grado promedio es efectivamente (n-1)*p = (299)(0.015) = 4.5, aprox 5

# %%
G2.number_of_edges()
# Out:
# 683

# %% [markdown]
# Podemos ver que el número promedio de aristas a esperar sería (from n choose 2) * p = 44850*0.015 = 672.75 o 673, habiendo 683 aristas, el grafo es relativamente común.

# %% [markdown]
# Este modelo también se usa en lo mismo que el anterior, sin embargo, Erdös Rényi tiene aplicaciones en la teoría de la percolación.
